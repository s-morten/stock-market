# %%
from currency_converter import ECB_URL, CurrencyConverter

c = CurrencyConverter()

# %%
c.currencies

# %%
import yfinance as yf

# %%
# market data

# Define a list of popular market indices and major stocks
indices = ['^GSPC', '^ACWI', '^STOXX50E', '^N225']  # S&P 500, MSCI All Country World Index, Euro Stoxx 50

# Fetch data
market_data = yf.download(indices, period="1d", interval="1d")

# Display the data
print(market_data.tail())  # Display the last few rows of the data to check the most recent values

# %%
import yfinance as yf

dat = yf.Ticker("MSFT")

# %%
dat.cashflow

# %%
# Get Microsoft stock data
msft = yf.Ticker("MSFT")

# Fetch the P/E ratio
pe_ratio = msft.info['trailingPE']  # trailingPE provides the trailing P/E ratio

print(f"The P/E ratio of Microsoft is: {pe_ratio}")
